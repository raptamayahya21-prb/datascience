# %% [markdown]
# ### Seaborn

# %% [markdown]
# tiga pilar seaborn:
#
# 1. high-level interface.
# 2. integrasi dengan pandas.
# 3. estetika yang menarik.

# %% [markdown]
# ### 1. Membuat Plot Dengan Seaborn

# %%
# import
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# membuat data set dari bawaan seaborn
tips_df = sns.load_dataset('tips')
print(tips_df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_theme(style="whitegrid")
sns.scatterplot(data=tips_df, x="total_bill", y="tip")

plt.show()

# %%
plt.Figure(figsize=(8,4))
plt.scatter(tips_df['total_bill'], tips_df['tip'])
plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()
# Out:
# C:\Users\ADVAN\AppData\Local\Temp\ipykernel_18112\3007041111.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
